# %% [markdown]
# ## Neural Tolstoy Model (a character-prediction LSTM)
#
# In this part you will train a character prediction LSTM that predicts the next character given previous characters.
# The training data is from the book "War and Peace" by Leo Tolstoy.

# %%
from __future__ import print_function
import datetime
import os
import numpy as np
import tensorflow as tf
import tolstoy_reader

def get_default_gpu_session(fraction=0.333):
    config = tf.ConfigProto(allow_soft_placement=True)
    config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = fraction
    return tf.Session(config=config)

def run_tolstoy_train(n_hid):
    # generate data
    btg, map_dict, backmap_dict = \
        tolstoy_reader.batch_tolstoy_generator(batch_size=200, seq_size=100)
    shape = dict(n_steps_per_batch=100, n_unique_ids=len(map_dict), n_hidden_dim=n_hid)
    # define LSTM
    model = build_lstm_discrete_prediction_model(shape)
    
    #logdir = './tensorboard/tolstoy'  # if on Windows
    logdir = 'tolstoy'  # if on Unix
    try:
        os.makedirs(logdir)
    except os.error:
        pass
    time_now = datetime.datetime.now().strftime("%d-%b-%H-%M-%S")
    run_name = 'hidden=%d' % n_hid
    sum_path = os.path.join(logdir, run_name + '_' + time_now)
    print(sum_path)
    max_iter_i = 0
    with model['graph'].as_default() as g, get_default_gpu_session(0.9) as sess:
        sess.run(tf.global_variables_initializer())
        sum_writer = tf.summary.FileWriter(sum_path, g)
        for epoch_i in range(10):
            for iter_i, data_batch in enumerate(btg):
                max_iter_i = max(iter_i, max_iter_i)
                global_step = epoch_i*max_iter_i+iter_i
                
                # run training step
                train_feed_dict = dict(zip(model['inputs'], data_batch))
                to_compute = [model['train_op'], model['summ'], model['loss']]
                _, summ, loss_val = sess.run(to_compute, train_feed_dict)
                
                # for tensorboard
                sum_writer.add_summary(summ, global_step)
                sum_writer.flush()
                
                # display loss
                if iter_i % 100 == 0:
                    print(loss_val, end=', ')
                if iter_i % 1000:
                    continue
                # test generation
                pred_length = 50
                data_input = next(iter(btg))[0][[0]]
                original_sample = data_input.copy()
                pred_seq = []
                for _ in range(pred_length):
                    pred = sess.run(model['pred'], {model['inputs'][0]: data_input})
                    pred_seq.append(pred[0])
                    data_input = np.roll(data_input, -1, axis=1)
                    data_input[0, -1] = pred[0]
                print('[%d] Input text:' % (iter_i))
                print(''.join([backmap_dict[x] for x in original_sample[0]]))
                print('[%d] Generated continuation:' % (iter_i))
                print(''.join([backmap_dict[x] for x in pred_seq]))
                print(pred_seq)
                print()
                
def build_lstm_discrete_prediction_model(shape):
    # shape is dict with keys:
    # n_steps_per_batch, n_unique_ids, n_hidden_dim
    with tf.Graph().as_default() as g:
        X = tf.placeholder(tf.float32, [None, shape['n_steps_per_batch']])
        y = tf.placeholder(tf.int32, [None])
        
        ################################################################
        ####################   PUT YOUR CODE HERE   ####################
        # define LSTM parameters (scope: weights)
        with tf.variable_scope('weights'):
            
            w_i = tf.get_variable('W_i', [1,shape['n_hidden_dim']])
            w_f = tf.get_variable('W_f', [1,shape['n_hidden_dim']])
            w_c = tf.get_variable('W_c', [1,shape['n_hidden_dim']])
            w_o = tf.get_variable('W_o', [1,shape['n_hidden_dim']])
            
            u_i = tf.get_variable('U_i', [shape['n_hidden_dim'] , shape['n_hidden_dim']])
            u_f = tf.get_variable('U_f', [shape['n_hidden_dim'] , shape['n_hidden_dim']])
            u_c = tf.get_variable('U_c', [shape['n_hidden_dim'] , shape['n_hidden_dim']])
            u_o = tf.get_variable('U_o', [shape['n_hidden_dim'] , shape['n_hidden_dim']])
            
            v_o = tf.get_variable('V_o', [shape['n_hidden_dim'] , shape['n_hidden_dim']])
            
            w_y = tf.get_variable('W_y', [shape['n_hidden_dim'] , shape['n_unique_ids']])
            
            h_0 = tf.get_variable('h_0', [1,shape['n_hidden_dim']])
            c_0 = tf.get_variable('c_0' , [1,shape['n_hidden_dim']])
            
            c_t = c_0
            h_t = h_0
            for t in range(shape['n_steps_per_batch']):
                xt = X[:,t]
                x_t = tf.reshape(xt,[-1,1])
                i_t = tf.nn.sigmoid(tf.matmul(x_t,w_i) + tf.matmul (h_t,u_i))
                c_bar_t = tf.nn.tanh(tf.matmul(x_t,w_c) + tf.matmul (h_t,u_c))
                f_t = tf.nn.sigmoid(tf.matmul(x_t,w_f) + tf.matmul (h_t,u_f))
                c_t = tf.multiply(i_t,c_bar_t) + tf.multiply(f_t,c_t)
                o_t = tf.nn.sigmoid(tf.matmul(x_t,w_o) + tf.matmul (h_t,u_o) + tf.matmul(c_t,v_o))
                h_t = tf.multiply(o_t,tf.tanh(c_t))   
            
        
        output = h_t  # put your result in variable 'output' 
            
            
        logits = tf.matmul(h_t,w_y)  # compute logits for each discrete output
        losses = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
        loss = tf.reduce_mean(losses)  
        ################################################################

        # pred, train_op
        pred = tf.argmax(logits, axis=1)
        train_op = tf.train.AdamOptimizer().minimize(loss)
        summ = tf.summary.scalar('loss_summ', loss)

    return {'inputs': [X, y], 'loss': loss, 'train_op': train_op, 'summ': summ,
            'graph': g, 'pred': pred}

# %% [markdown]
# Run the LSTM and see what it says!

# %%
hidden = 200
run_tolstoy_train(hidden)
# Out:
# tolstoy/hidden=200_24-Apr-21-03-36
# 4.43514, [0] Input text:
#  weason to ask to be pwomoted to be a German! Now p'waps Wussians will get a look in. As it was, dev
# [0] Generated continuation:
# F(F(FFFFFFFFFFFGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG
# [74, 39, 74, 39, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 74, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76, 76]
#
# 2.98381, 2.8111, 2.79532, 2.7886, 2.78853, 2.71783, 2.59134, 2.72734, 2.54428, 2.49091, [1000] Input text:
# he real relation of the forces had already made itself felt in Petersburg, was dispatched, Kutuzov h
# [1000] Generated continuation:
# is the the the the the the the the the the the the
# [79, 22, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38, 11, 69, 43, 38]
#
# 2.6716, 2.26178, 2.32184, 2.30663, 2.18396, 2.25039, 2.37151, 2.39892, 2.27076, 2.41767, [2000] Input text:
# 's wife. "Kindly let this cart pass. Don't you see it's a woman?" said Prince Andrew riding up to th
# [2000] Generated continuation:
# e core and the core and the core and the core and
# [38, 11, 61, 9, 72, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 72, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 72, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 72, 38, 11, 52, 13, 78, 11]
#
# 2.20705, 2.29071, 2.30282, 2.2549, 2.22049, 2.20716, 2.17148, 2.23884, 2.31521, 2.0591, [3000] Input text:
# re dragged from the front, the wounded carried away, and the ranks closed up. If any soldiers ran to
# [3000] Generated continuation:
#  the sas some and the sas some and the sas some an
# [11, 69, 43, 38, 11, 22, 52, 22, 11, 22, 9, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 22, 11, 22, 9, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 22, 11, 22, 9, 56, 38, 11, 52, 13]
#
# 2.29524, 2.20853, 2.2482, 2.17581, 2.2463, 2.25315, 2.26036, 2.08421, 2.2796, 1.97407, [4000] Input text:
# s of others, and had he at all understood what Pierre's feelings were, the latter would probably hav
# [4000] Generated continuation:
# e the said the said the said the said the said the
# [38, 11, 69, 43, 38, 11, 22, 52, 79, 78, 11, 69, 43, 38, 11, 22, 52, 79, 78, 11, 69, 43, 38, 11, 22, 52, 79, 78, 11, 69, 43, 38, 11, 22, 52, 79, 78, 11, 69, 43, 38, 11, 22, 52, 79, 78, 11, 69, 43, 38]
#
# 2.04543, 2.11736, 2.12639, 2.08069, 2.12084, 2.19751, 1.9231, 2.24958, 1.97627, 1.93951, [5000] Input text:
# s entering the ballroom, the Emperor made a wry face and muttered something in which some people cau
# [5000] Generated continuation:
# se the conting the conting the conting the conting
# [22, 38, 11, 69, 43, 38, 11, 61, 9, 13, 69, 79, 13, 31, 11, 69, 43, 38, 11, 61, 9, 13, 69, 79, 13, 31, 11, 69, 43, 38, 11, 61, 9, 13, 69, 79, 13, 31, 11, 69, 43, 38, 11, 61, 9, 13, 69, 79, 13, 31]
#
# 2.09129, 1.99417, 2.1025, 1.85417, 2.07219, 2.14211, 1.81715, 2.13234, 2.08329, 2.28191, [6000] Input text:
# French and saw Tikhon and learned that there would certainly be an attack that night, he decided, wi
# [6000] Generated continuation:
# th a soldier and the sas and the sas and the sas a
# [69, 43, 11, 52, 11, 22, 9, 2, 78, 79, 38, 72, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 22, 11, 52]
#
# 2.1483, 2.04896, 1.87321, 1.98359, 2.05192, 1.9473, 2.18709, 1.70161, 2.00634, 2.0049, [7000] Input text:
# ily to the dressers. His very first, remotest recollections of childhood came back to Prince Andrew'
# [7000] Generated continuation:
#  and the sasser the sasser the sasser the sasser t
# [11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 22, 22, 38, 72, 11, 69, 43, 38, 11, 22, 52, 22, 22, 38, 72, 11, 69, 43, 38, 11, 22, 52, 22, 22, 38, 72, 11, 69, 43, 38, 11, 22, 52, 22, 22, 38, 72, 11, 69]
#
# 1.96735, 1.81645, 1.91037, 2.10195, 1.79762, 1.99494, 2.13189, 1.95858, 1.97356, 1.8552, [8000] Input text:
# hroat to draw attention. "Did you hear of the last event at the review in Petersburg? The figure cut
# [8000] Generated continuation:
# e and the count of the count of the count of the c
# [38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61]
#
# 1.92648, 1.96644, 1.99612, 2.08931, 1.97426, 1.89787, 2.029, 1.84575, 1.88403, 1.81195, [9000] Input text:
#  and the possessor of such enormous wealth, to the caprice of fate and the designs of rogues. During
# [9000] Generated continuation:
#  the sornd of the sornd of the sornd of the sornd
# [11, 69, 43, 38, 11, 22, 9, 72, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 72, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 72, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 72, 13, 78, 11]
#
# 1.94754, 1.94357, 1.76041, 1.94967, 1.75289, 1.7549, 1.86544, 1.79601, 1.90108, 1.83716, [10000] Input text:
# .." Merry senseless words of abuse flowed freely. "What are you up to?" suddenly came the authoritat
# [10000] Generated continuation:
# ion of the say the say the say the say the say the
# [79, 9, 13, 11, 9, 65, 11, 69, 43, 38, 11, 22, 52, 42, 11, 69, 43, 38, 11, 22, 52, 42, 11, 69, 43, 38, 11, 22, 52, 42, 11, 69, 43, 38, 11, 22, 52, 42, 11, 69, 43, 38, 11, 22, 52, 42, 11, 69, 43, 38]
#
# 1.85499, 1.94597, 1.7468, 1.75824, 1.9027, 1.79059, 1.84177, 1.67915, 1.75831, 1.70567, [11000] Input text:
# one man's life." "Won't you come over to the other table?" suggested Anna Pavlovna. But Pierre conti
# [11000] Generated continuation:
# nged the soldiers and the soldiers and the soldier
# [13, 31, 38, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72]
#
# 1.9296, 1.8875, 1.72255, 1.9413, 1.91899, 1.9229, 1.84295, 1.83488, 1.82105, 1.81746, [12000] Input text:
# stood carriages, wagons, and crowds of orderlies and sentinels. The commander-in-chief was putting u
# [12000] Generated continuation:
# esired to the say and the say and the say and the
# [38, 22, 79, 72, 38, 78, 11, 69, 9, 11, 69, 43, 38, 11, 22, 52, 42, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 42, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 42, 11, 52, 13, 78, 11, 69, 43, 38, 11]
#
# 1.65513, 1.8337, 1.95857, 1.85086, 1.70313, 1.90613, 1.81948, 1.61315, 1.73511, 2.03005, [13000] Input text:
# speaking about Napoleons, Louis-es, and authors, we ought to be shown the connection existing betwee
# [13000] Generated continuation:
#  and the sasse and something to the countess of th
# [11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 22, 22, 38, 11, 52, 13, 78, 11, 22, 9, 56, 38, 69, 43, 79, 13, 31, 11, 69, 9, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43]
#
# 1.99572, 1.84565, 1.79311, 1.86983, 1.79705, 1.74663, 1.77263, 1.87753, 1.72325, 1.93579, [14000] Input text:
# laced a bottle of claret in it. He also brought a bottle of kvass, taken from the kitchen for them t
# [14000] Generated continuation:
# he soldier and sere she had seen he had seen he ha
# [43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 11, 52, 13, 78, 11, 22, 38, 72, 38, 11, 22, 43, 38, 11, 43, 52, 78, 11, 22, 38, 38, 13, 11, 43, 38, 11, 43, 52, 78, 11, 22, 38, 38, 13, 11, 43, 38, 11, 43, 52]
#
# 1.76583, 1.97725, 1.90083, 1.73678, 1.6205, 1.85667, 1.56716, 2.06382, 1.86657, 1.77755, [15000] Input text:
# y to the honor of our nation. Do not break your ranks on the plea of removing the wounded! Let every
# [15000] Generated continuation:
#  of the soldier of the soldier of the soldier of t
# [11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 11, 9, 65, 11, 69]
#
# 1.77235, 1.86643, 1.70286, 1.76312, 1.83855, 1.81579, 1.77451, 1.73087, 1.78987, 1.8639, [16000] Input text:
# r, so strange that Petya thought the French would immediately detect their disguise, and involuntari
# [16000] Generated continuation:
# ly and the soldiers of the soldiers of the soldier
# [2, 42, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72]
#
# 1.87638, [0] Input text:
# ich was really true. From the very first days of their married life Natasha had announced her demand
# [0] Generated continuation:
# e and the sound of the commander of the commander
# [38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 56, 56, 52, 13, 78, 38, 72, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 56, 56, 52, 13, 78, 38, 72, 11]
#
# 1.66159, 1.70621, 1.68647, 1.84874, 1.76171, 1.87305, 1.78243, 1.75463, 1.82454, 1.57679, [1000] Input text:
# d began: "Oh, my bower, oh, my bower...!" "Oh, my bower new...!" chimed in twenty voices, and the ca
# [1000] Generated continuation:
# n were and the countess of the countess of the cou
# [13, 11, 25, 38, 72, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73]
#
# 1.71233, 1.62436, 1.86294, 1.68178, 1.75721, 1.90147, 1.52346, 1.76422, 1.74871, 1.83469, [2000] Input text:
# ng she expected several important personages who had to be made ashamed of their visits to the Frenc
# [2000] Generated continuation:
# h of the soldiers and the soldiers and the soldier
# [43, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72]
#
# 1.85272, 1.8553, 1.72486, 1.76257, 1.69404, 1.83052, 1.8654, 1.88741, 1.59935, 1.82986, [3000] Input text:
# p. "I don't want to marry anyone. And I'll tell him so when I see him!" "Dear me!" said Rostov. "But
# [3000] Generated continuation:
#  the countess and the countess and and the countes
# [11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22]
#
# 1.62763, 1.76158, 1.41806, 1.47178, 1.66172, 1.79479, 1.75469, 1.72531, 1.90067, 1.815, [4000] Input text:
# ughed. She hardly ever left the house and of those who came to see them was glad to see only one per
# [4000] Generated continuation:
# y something the sayen the sayen the sayen the saye
# [42, 11, 22, 9, 56, 38, 69, 43, 79, 13, 31, 11, 69, 43, 38, 11, 22, 52, 42, 38, 13, 11, 69, 43, 38, 11, 22, 52, 42, 38, 13, 11, 69, 43, 38, 11, 22, 52, 42, 38, 13, 11, 69, 43, 38, 11, 22, 52, 42, 38]
#
# 1.72439, 1.50131, 1.72097, 1.77067, 1.68097, 1.65904, 1.80201, 1.58561, 1.74151, 1.79398, [5000] Input text:
# ere the rows of hay are lying in the hollow, there's the bridge. That's our center. Our right flank
# [5000] Generated continuation:
# the said of the said of the said of the said of th
# [69, 43, 38, 11, 22, 52, 79, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 52, 79, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 52, 79, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 52, 79, 78, 11, 9, 65, 11, 69, 43]
#
# 1.585, 1.72887, 1.8065, 1.63534, 1.77557, 1.4535, 1.65269, 1.6808, 1.53446, 1.70582, [6000] Input text:
# f the law of Copernicus the Ptolemaic worlds were still studied for a long time. From the time the f
# [6000] Generated continuation:
# ace of the countess and the countess and the soldi
# [52, 61, 38, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79]
#
# 1.48395, 1.72444, 1.70357, 1.65458, 1.60914, 1.87436, 1.74692, 1.72599, 1.85876, 1.57509, [7000] Input text:
# ved fresh appointments. Everyone spoke loudly of the field marshal's great weakness and failing heal
# [7000] Generated continuation:
# ts and the countess of the countess of the countes
# [69, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22]
#
# 1.80837, 1.85332, 1.72529, 1.67065, 1.57403, 1.58756, 1.60709, 1.68357, 1.73419, 1.66408, [8000] Input text:
# le words, her look, and the expression on her face which accompanied them, formed for two months the
# [8000] Generated continuation:
#  countess of the countess of the countess of the c
# [11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61]
#
# 1.63421, 1.69807, 1.54044, 1.78674, 1.61753, 1.54627, 1.7587, 1.69842, 1.58495, 1.71537, [9000] Input text:
# hirt. "I say, this is folly! He'll be killed," said this more sensible man. Anatole stopped him. "Do
# [9000] Generated continuation:
# u kany the soldiers of the countess of the countes
# [73, 11, 58, 52, 13, 42, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22]
#
# 1.67529, 1.62467, 1.84264, 1.60771, 1.66057, 1.608, 1.61309, 1.70382, 1.77749, 1.65666, [10000] Input text:
# e and that Anatole meant to flirt with Mademoiselle Bourienne, Princess Mary's self-esteem would be
# [10000] Generated continuation:
# and so and the countess of the count of the count
# [52, 13, 78, 11, 22, 9, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11]
#
# 1.69542, 1.46219, 1.84265, 1.61527, 1.51758, 1.73747, 1.50437, 1.45213, 1.74482, 1.73529, [11000] Input text:
# Please step inside, your honor!" "Talk indeed!" cried the thin one. "In my three shops here I have a
# [11000] Generated continuation:
#  soldiers and the sound of the soldiers and the so
# [11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9]
#
# 1.71008, 1.60804, 1.62751, 1.60394, 1.72572, 1.63372, 1.62081, 1.77077, 1.61343, 1.89497, [12000] Input text:
#  by Brother A. Though I am unworthy, much was revealed to me. Adonai is the name of the creator of t
# [12000] Generated continuation:
# he sounds of the sounds of the sounds of the sound
# [43, 38, 11, 22, 9, 73, 13, 78, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78]
#
# 1.5468, 1.78021, 1.75443, 1.81768, 1.60937, 1.65757, 1.67029, 1.60372, 1.82536, 1.65668, [13000] Input text:
# ose Natasha. Though with the intimacy now established between the wounded man and Natasha the though
# [13000] Generated continuation:
# t of the soldiers of the soldiers of the soldiers
# [69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11]
#
# 1.73009, 1.81797, 1.81666, 1.57915, 1.56926, 1.59726, 1.69457, 1.77786, 1.68922, 1.57125, [14000] Input text:
# r her, Natasha sat down on the floor, took her old ball dress, and fell into a reverie quite unrelat
# [14000] Generated continuation:
# y and the countess of the countess of the countess
# [42, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22]
#
# 1.55568, 1.65378, 1.73666, 1.7213, 1.55596, 1.52046, 1.5946, 1.86709, 1.45802, 1.76956, [15000] Input text:
# ich Napoleon had ordered up after four o'clock. The people did not at once realize the meaning of th
# [15000] Generated continuation:
# e countess who had been and the countess who had b
# [38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 9, 11, 43, 52, 78, 11, 12, 38, 38, 13, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 9, 11, 43, 52, 78, 11, 12]
#
# 1.51431, 1.72688, 1.5118, 1.73656, 1.58206, 1.4283, 1.57813, 1.61428, 1.59504, 1.55685, [16000] Input text:
#  for that very reason he could not understand how the man who put them there behind the hill could h
# [16000] Generated continuation:
# ave the soldiers and the countess who had been so
# [52, 16, 38, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 9, 11, 43, 52, 78, 11, 12, 38, 38, 13, 11, 22, 9, 11]
#
# 1.56094, [0] Input text:
# Not one of those dismounted cavalrymen who had marched in front of the prisoners was left; they had
# [0] Generated continuation:
# been and the same and the same and the same and th
# [12, 38, 38, 13, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43]
#
# 1.4895, 1.46346, 1.51287, 1.73498, 1.7092, 1.50717, 1.4628, 1.64428, 1.41374, 1.67818, [1000] Input text:
#  puckered his lips when Anisya Fedorovna entered. On the tray was a bottle of herb wine, different k
# [1000] Generated continuation:
# an and the same and the same and the same and the
# [52, 13, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11]
#
# 1.63884, 1.79165, 1.69945, 1.41038, 1.6638, 1.58807, 1.60615, 1.59467, 1.74353, 1.50832, [2000] Input text:
# he was calling on the Rostovs for that purpose. The idea of throwing her brother and Natasha togethe
# [2000] Generated continuation:
# r and the standing of the standing of the standing
# [72, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31]
#
# 1.66159, 1.61287, 1.60568, 1.4391, 1.61072, 1.58697, 1.57985, 1.70694, 1.90366, 1.6556, [3000] Input text:
#  with the suppressed emotion of a man re-experiencing in recollection strong impressions he has live
# [3000] Generated continuation:
# d the same and the counte and the soldiers and the
# [78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38]
#
# 1.51227, 1.52723, 1.76057, 1.69432, 1.60827, 1.64784, 1.84038, 1.67015, 1.62073, 1.65545, [4000] Input text:
# boda Palace. The great halls were full. In the first were the nobility and gentry in their uniforms,
# [4000] Generated continuation:
#  and the old man and the old man and the old man a
# [11, 52, 13, 78, 11, 69, 43, 38, 11, 9, 2, 78, 11, 56, 52, 13, 11, 52, 13, 78, 11, 69, 43, 38, 11, 9, 2, 78, 11, 56, 52, 13, 11, 52, 13, 78, 11, 69, 43, 38, 11, 9, 2, 78, 11, 56, 52, 13, 11, 52]
#
# 1.65477, 1.49989, 1.48438, 1.54447, 1.59967, 1.70273, 1.6215, 1.68327, 1.53108, 1.42868, [5000] Input text:
# p to the group and shouted at Mishka. "What are you staring at, you good-for-nothing?... The count w
# [5000] Generated continuation:
# hich he had not the soldiers and the soldiers was
# [43, 79, 61, 43, 11, 43, 38, 11, 43, 52, 78, 11, 13, 9, 69, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 25, 52, 22, 11]
#
# 1.4992, 1.49682, 1.29413, 1.48999, 1.62781, 1.4281, 1.5183, 1.63242, 1.40934, 1.67554, [6000] Input text:
#  about in his soft boots between the dining and drawing rooms, hastily greeting the important and un
# [6000] Generated continuation:
# der the countess was the countess was the countess
# [78, 38, 72, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 52, 22, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 52, 22, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22]
#
# 1.7152, 1.67142, 1.51629, 1.57472, 1.6095, 1.33531, 1.69146, 1.59317, 1.52089, 1.71935, [7000] Input text:
# ar!" shouted the colonel, again thumping the table. "What are you making such a noise about over the
# [7000] Generated continuation:
#  story of the story of the story of the story of t
# [11, 22, 69, 9, 72, 42, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 9, 72, 42, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 9, 72, 42, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 9, 72, 42, 11, 9, 65, 11, 69]
#
# 1.56613, 1.54239, 1.76592, 1.60022, 1.73054, 1.58929, 1.65239, 1.5006, 1.66311, 1.67622, [8000] Input text:
# their sleeves!" said Anna Mikhaylovna, pointing to Nicholas as he went out. "Cousinage-- dangereux v
# [8000] Generated continuation:
# ostov was so on a soldiers and she had been she sa
# [9, 22, 69, 9, 16, 11, 25, 52, 22, 11, 22, 9, 11, 9, 13, 11, 52, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 22, 43, 38, 11, 43, 52, 78, 11, 12, 38, 38, 13, 11, 22, 43, 38, 11, 22, 52]
#
# 1.59665, 1.7014, 1.55183, 1.54903, 1.58816, 1.42115, 1.53199, 1.55015, 1.73486, 1.54674, [9000] Input text:
#  Petersburg on my pay, and with her fortune and my good management we can get along nicely. I am not
# [9000] Generated continuation:
#  the countess which he was not the countess which
# [11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 79, 61, 43, 11, 43, 38, 11, 25, 52, 22, 11, 13, 9, 69, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 79, 61, 43, 11]
#
# 1.62343, 1.64333, 1.56562, 1.55432, 1.48604, 1.62665, 1.50254, 1.7405, 1.5556, 1.592, [10000] Input text:
#  He was filled with happiness at his nearness to the Emperor. He felt that this nearness by itself m
# [10000] Generated continuation:
# en who had been still he had been still he had bee
# [38, 13, 11, 25, 43, 9, 11, 43, 52, 78, 11, 12, 38, 38, 13, 11, 22, 69, 79, 2, 2, 11, 43, 38, 11, 43, 52, 78, 11, 12, 38, 38, 13, 11, 22, 69, 79, 2, 2, 11, 43, 38, 11, 43, 52, 78, 11, 12, 38, 38]
#
# 1.52006, 1.58433, 1.63478, 1.68649, 1.4688, 1.4836, 1.52742, 1.49905, 1.51493, 1.72906, [11000] Input text:
# ll always regard you as a benefactor," she added hurriedly. "No, don't be angry, but promise! I have
# [11000] Generated continuation:
#  ye was the sound of the solence of the solence of
# [11, 42, 38, 11, 25, 52, 22, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 38, 13, 61, 38, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 38, 13, 61, 38, 11, 9, 65]
#
# 1.69504, 1.63584, 1.53614, 1.47638, 1.73359, 1.56527, 1.41113, 1.54233, 1.73946, 1.50207, [12000] Input text:
#  the permission of the copyright holder found at the beginning of this work. 1.E.4. Do not unlink or
# [12000] Generated continuation:
#  the countess were all the countess and the counte
# [11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 38, 72, 38, 11, 52, 2, 2, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38]
#
# 1.62298, 1.47505, 1.52123, 1.44154, 1.55944, 1.46145, 1.78347, 1.38539, 1.78943, 1.63864, [13000] Input text:
# ed in an ordinary and simple way. Both Princess Mary and Natasha, who did not leave him, felt this.
# [13000] Generated continuation:
# "I was the soldiers of the soldiers of the soldier
# [26, 23, 11, 25, 52, 22, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72]
#
# 1.60394, 1.74341, 1.65458, 1.59966, 1.48827, 1.57658, 1.50207, 1.38099, 1.63483, 1.56182, [14000] Input text:
# said the count, muttering some indefinite order. But at the same moment an expression of warm gratit
# [14000] Generated continuation:
# ing the soldiers of the soldiers of the soldiers o
# [79, 13, 31, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9]
#
# 1.56604, 1.52931, 1.70528, 1.53631, 1.78353, 1.72267, 1.69292, 1.5263, 1.5284, 1.64936, [15000] Input text:
# he groans and voices of the wounded were more distinctly heard than any other sound in the darkness
# [15000] Generated continuation:
# of the soldiers of the soldiers of the soldiers of
# [9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65]
#
# 1.53825, 1.646, 1.54877, 1.67603, 1.5392, 1.51883, 1.30813, 1.68153, 1.64767, 1.48108, [16000] Input text:
#  the battle had not yet begun. Not wishing to agree to Dolgorukov's demand to commence the action, a
# [16000] Generated continuation:
# nd the same and the same and the same and the same
# [13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38]
#
# 1.67108, [0] Input text:
# d. The flogging was only just over, and the executioner was releasing from the flogging bench a stou
# [0] Generated continuation:
# t the soldiers and the soldiers and the soldiers a
# [69, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52]
#
# 1.53381, 1.56732, 1.43743, 1.52646, 1.50174, 1.70343, 1.53442, 1.6001, 1.63177, 1.61453, [1000] Input text:
# llowed it and the flight of the French without further conflicts, is one of the most instructive phe
# [1000] Generated continuation:
# ss and the countess who was the sounds of the sold
# [22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 9, 11, 25, 52, 22, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78]
#
# 1.66553, 1.64708, 1.43068, 1.61926, 1.50756, 1.5041, 1.72117, 1.53371, 1.44444, 1.57813, [2000] Input text:
# on at the address specified in Section 4, "Information about donations to the Project Gutenberg Lite
# [2000] Generated continuation:
#  the sound of the sound of the sound of the sound
# [11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11]
#
# 1.58045, 1.58016, 1.59486, 1.52718, 1.32934, 1.51045, 1.49446, 1.49027, 1.48838, 1.59443, [3000] Input text:
# d is as fresh as ever!" Soon after "Uncle's" reappearance the door was opened, evidently from the so
# [3000] Generated continuation:
# ldiers of the count was a soldiers of the count wa
# [2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 25, 52, 22, 11, 52, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 25, 52]
#
# 1.75853, 1.59121, 1.64867, 1.6086, 1.70811, 1.45044, 1.40983, 1.46274, 1.57101, 1.48391, [4000] Input text:
# tion; he said that all bodies from the largest to the smallest have the property of attracting one a
# [4000] Generated continuation:
# nother was a stood of the countess and the countes
# [13, 9, 69, 43, 38, 72, 11, 25, 52, 22, 11, 52, 11, 22, 69, 9, 9, 78, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22]
#
# 1.37294, 1.61453, 1.73835, 1.67679, 1.4505, 1.61053, 1.38196, 1.56697, 1.71496, 1.31013, [5000] Input text:
# he bushy edge of the road where he was to stand, arranged his reins, settled himself in the saddle,
# [5000] Generated continuation:
# and the countess where the soldiers of the soldier
# [52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 38, 72, 38, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72]
#
# 1.55342, 1.58761, 1.52278, 1.56025, 1.54669, 1.41626, 1.66091, 1.52205, 1.58694, 1.48862, [6000] Input text:
# id not repeat to himself with a sickening feeling of shame the words he had spoken, or say: "Oh, why
# [6000] Generated continuation:
#  who was not the soldiers and was a soldiers and w
# [11, 25, 43, 9, 11, 25, 52, 22, 11, 13, 9, 69, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 25, 52, 22, 11, 52, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 25]
#
# 1.44641, 1.48147, 1.58817, 1.65488, 1.44534, 1.56017, 1.60369, 1.56898, 1.7046, 1.52666, [7000] Input text:
# spicuous representative was the Tsarevich, who could not forget his disillusionment at Austerlitz, w
# [7000] Generated continuation:
# ith the countess were a soldiers and the countess
# [79, 69, 43, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 38, 72, 38, 11, 52, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11]
#
# 1.63152, 1.58956, 1.71754, 1.22759, 1.38625, 1.57968, 1.66245, 1.5322, 1.73936, 1.6692, [8000] Input text:
# l him of his intention to elope with a blonde lady. The husband smiled gloomily, the wife gaily. The
# [8000] Generated continuation:
#  countess and the standing to the standing to the
# [11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 69, 9, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 69, 9, 11, 69, 43, 38, 11]
#
# 1.69749, 1.39094, 1.41995, 1.53859, 1.66778, 1.41935, 1.40001, 1.44242, 1.5416, 1.61041, [9000] Input text:
# he Venerable Sergius. It was regarded as a model of ecclesiastical, patriotic eloquence. Prince Vasi
# [9000] Generated continuation:
# li to the commander was a soldiers and the command
# [2, 79, 11, 69, 9, 11, 69, 43, 38, 11, 61, 9, 56, 56, 52, 13, 78, 38, 72, 11, 25, 52, 22, 11, 52, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 56, 56, 52, 13, 78]
#
# 1.54359, 1.60404, 1.75201, 1.56536, 1.44205, 1.66847, 1.60165, 1.47804, 1.61747, 1.71025, [10000] Input text:
#  dull boy of thirteen could have guessed that the best position for an army after its retreat from M
# [10000] Generated continuation:
# atasha was a solemn army and the soldiers and the
# [52, 69, 52, 22, 43, 52, 11, 25, 52, 22, 11, 52, 11, 22, 9, 2, 38, 56, 13, 11, 52, 72, 56, 42, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11]
#
# 1.53912, 1.53665, 1.6533, 1.35338, 1.50487, 1.48046, 1.49371, 1.46945, 1.46307, 1.40194, [11000] Input text:
# he town. "Helene, who has never cared for anything but her own body and is one of the stupidest wome
# [11000] Generated continuation:
# n to the countess and the countess and the countes
# [13, 11, 69, 9, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22]
#
# 1.35958, 1.46339, 1.51078, 1.18634, 1.57918, 1.72161, 1.35971, 1.50239, 1.28619, 1.51166, [12000] Input text:
# ing the commander-in-chief's suite. He was in a state of suppressed excitement and irritation, thoug
# [12000] Generated continuation:
# h the countess and the countess and the countess a
# [43, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52]
#
# 1.56197, 1.43836, 1.57592, 1.45443, 1.60669, 1.66298, 1.58745, 1.4684, 1.6012, 1.4112, [13000] Input text:
# ting but hardly feasible." "You think so?" rejoined Anna Pavlovna in order to say something and get
# [13000] Generated continuation:
# dt was not a strange and the same the same the sam
# [78, 69, 11, 25, 52, 22, 11, 13, 9, 69, 11, 52, 11, 22, 69, 72, 52, 13, 31, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 69, 43, 38, 11, 22, 52, 56]
#
# 1.45667, 1.51368, 1.7359, 1.43576, 1.26336, 1.49548, 1.54922, 1.36299, 1.33588, 1.45534, [14000] Input text:
# ual was such as could certainly not have caused him to expect that honor. The prince, who generally
# [14000] Generated continuation:
# and the sound of the sound of the sound of the sou
# [52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73]
#
# 1.39969, 1.59949, 1.31726, 1.40734, 1.53294, 1.33542, 1.5736, 1.54255, 1.49227, 1.37649, [15000] Input text:
# reur!" just as they had cried "Vive l'Empereur!" at the sight of the portrait of the boy piercing th
# [15000] Generated continuation:
# e conceated and the conceated and the conceated an
# [38, 11, 61, 9, 13, 61, 38, 52, 69, 38, 78, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 13, 61, 38, 52, 69, 38, 78, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 13, 61, 38, 52, 69, 38, 78, 11, 52, 13]
#
# 1.52436, 1.60101, 1.64304, 1.40677, 1.63953, 1.58587, 1.4919, 1.61972, 1.53642, 1.55227, [16000] Input text:
# gold. "Is that their Tsar himself? He's not bad!" low voices could be heard saying. An interpreter r
# [16000] Generated continuation:
# eplied the strdca and the strdca and the strdca an
# [38, 19, 2, 79, 38, 78, 11, 69, 43, 38, 11, 22, 69, 72, 78, 61, 52, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 72, 78, 61, 52, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 72, 78, 61, 52, 11, 52, 13]
#
# 1.44627, [0] Input text:
# l of the cart and remained motionless a long while sunk in thought. Suddenly he burst out into a fit
# [0] Generated continuation:
# ion of the sound of the sound of the sound of the
# [79, 9, 13, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11]
#
# 1.4014, 1.67156, 1.40511, 1.6302, 1.47976, 1.5253, 1.65212, 1.49694, 1.56869, 1.46128, [1000] Input text:
# or his hand to deign to touch that soldier's breast for the soldier to be forever happy, rewarded, a
# [1000] Generated continuation:
# nd the couner the couner the couner the couner the
# [13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 38, 72, 11, 69, 43, 38, 11, 61, 9, 73, 13, 38, 72, 11, 69, 43, 38, 11, 61, 9, 73, 13, 38, 72, 11, 69, 43, 38, 11, 61, 9, 73, 13, 38, 72, 11, 69, 43, 38]
#
# 1.7417, 1.46517, 1.5622, 1.49494, 1.43581, 1.68642, 1.45009, 1.71523, 1.33772, 1.41828, [2000] Input text:
# s were rioting and robbing people on their way from Moscow, and so on. But all this was only talk; i
# [2000] Generated continuation:
# n the countess were the soldiers and the soldiers
# [13, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 38, 72, 38, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11]
#
# 1.55703, 1.55898, 1.56487, 1.42045, 1.40236, 1.4704, 1.40398, 1.57571, 1.39687, 1.46409, [3000] Input text:
#  would have happened! You know, Uncle promised me only the day before yesterday not to forget Boris.
# [3000] Generated continuation:
#  "I did not know that the soldiers and the soldier
# [11, 26, 23, 11, 78, 79, 78, 11, 13, 9, 69, 11, 58, 13, 9, 25, 11, 69, 43, 52, 69, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72]
#
# 1.41999, 1.4779, 1.62486, 1.57287, 1.5885, 1.32285, 1.46911, 1.47284, 1.68208, 1.53584, [4000] Input text:
# kly: "There is only one Paris in the world. You have been to Paris and have remained Russian. Well,
# [4000] Generated continuation:
# and had all the count of the count of the count of
# [52, 13, 78, 11, 43, 52, 78, 11, 52, 2, 2, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65]
#
# 1.4392, 1.2823, 1.48994, 1.50872, 1.37587, 1.46665, 1.36617, 1.27212, 1.35969, 1.4048, [5000] Input text:
# oke now he was considering what impression his words would make on Natasha. He did not purposely say
# [5000] Generated continuation:
# ing to the sounded and the countess were the sound
# [79, 13, 31, 11, 69, 9, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 38, 78, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 38, 72, 38, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78]
#
# 1.52075, 1.69594, 1.54102, 1.66032, 1.43282, 1.65031, 1.42312, 1.66986, 1.60911, 1.61747, [6000] Input text:
# hear and see. And he had only one wish-- that the frightful thing that had to happen should happen q
# [6000] Generated continuation:
# uite a battle of the soldiers and the soldiers and
# [73, 79, 69, 38, 11, 52, 11, 12, 52, 69, 69, 2, 38, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78]
#
# 1.19636, 1.37735, 1.43921, 1.39246, 1.68338, 1.39747, 1.46343, 1.53616, 1.53923, 1.49072, [7000] Input text:
# rooms leading the Tsar's beautiful relay horses covered with embroidered cloths. As when a window is
# [7000] Generated continuation:
#  the sound of the sound of the soldiers and the so
# [11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9]
#
# 1.64963, 1.47073, 1.32741, 1.5594, 1.49488, 1.3511, 1.26991, 1.56631, 1.38613, 1.59274, [8000] Input text:
# fault, had at once moved his forces to attack the center and outflank both the Russian wings, hoping
# [8000] Generated continuation:
#  the standing of the standing of the standing of t
# [11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 9, 65, 11, 69]
#
# 1.45324, 1.42374, 1.47433, 1.27906, 1.38942, 1.47721, 1.33856, 1.43184, 1.41415, 1.42616, [9000] Input text:
# e mystical aspect of Freemasonry. In the second category Pierre reckoned himself and others like him
# [9000] Generated continuation:
#  and the countess which had been and the countess
# [11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 79, 61, 43, 11, 43, 52, 78, 11, 12, 38, 38, 13, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11]
#
# 1.50317, 1.22569, 1.49924, 1.64725, 1.38316, 1.41166, 1.54599, 1.69626, 1.45116, 1.24623, [10000] Input text:
# aughing voices. "How can they laugh, or even live at all here?" thought Rostov, still aware of that
# [10000] Generated continuation:
# the countess which he had the sound of the countes
# [69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 79, 61, 43, 11, 43, 38, 11, 43, 52, 78, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22]
#
# 1.5022, 1.57984, 1.50772, 1.33242, 1.43135, 1.42855, 1.41406, 1.62779, 1.64005, 1.38485, [11000] Input text:
# n for that evening. Sonya knocked at her door. Natasha did not let her in. "She will run away with h
# [11000] Generated continuation:
# is son with the stranger of the stranger of the st
# [79, 22, 11, 22, 9, 13, 11, 25, 79, 69, 43, 11, 69, 43, 38, 11, 22, 69, 72, 52, 13, 31, 38, 72, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 72, 52, 13, 31, 38, 72, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69]
#
# 1.60401, 1.49812, 1.41287, 1.58477, 1.49427, 1.54697, 1.50202, 1.60776, 1.46359, 1.41528, [12000] Input text:
# ee!" "Yes, but it is not as you imagine," Prince Andrew continued. "I did not, and do not, in the le
# [12000] Generated continuation:
# ft the sound of the soldiers and the sound of the
# [65, 69, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11]
#
# 1.40359, 1.43755, 1.43276, 1.62961, 1.56313, 1.60799, 1.68203, 1.46434, 1.52583, 1.74625, [13000] Input text:
# rying, and had grown quite reconciled to her lot as a sterile flower. She seemed to be fond not so m
# [13000] Generated continuation:
# an and the stands of the stands of the stands of t
# [52, 13, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 22, 11, 9, 65, 11, 69]
#
# 1.30644, 1.41099, 1.58402, 1.45666, 1.51622, 1.4996, 1.33006, 1.44842, 1.48436, 1.36195, [14000] Input text:
# llow with a triumphant smile on his lips and a frown on his brow), "to consult with him to act, and
# [14000] Generated continuation:
# the soldiers of the street of the soldiers of the
# [69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 72, 38, 38, 69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11]
#
# 1.59035, 1.53817, 1.33644, 1.30223, 1.3457, 1.48758, 1.46232, 1.47981, 1.32057, 1.40942, [15000] Input text:
# ghtened that she woke Sonya and told her what she had done. The necessary antidotes had been adminis
# [15000] Generated continuation:
#  of the contrary of the contrary of the contrary o
# [11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 13, 69, 72, 52, 72, 42, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 13, 69, 72, 52, 72, 42, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 13, 69, 72, 52, 72, 42, 11, 9]
#
# 1.40079, 1.62662, 1.42408, 1.46637, 1.29204, 1.49724, 1.61743, 1.50726, 1.56704, 1.43816, [16000] Input text:
# er that it must all be kept from her father and assuring her that nobody would know anything about i
# [16000] Generated continuation:
# n the contrary of the soldiers and any of the sold
# [13, 11, 69, 43, 38, 11, 61, 9, 13, 69, 72, 52, 72, 42, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 52, 13, 42, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78]
#
# 1.50131, [0] Input text:
#  reassured as to the general course of affairs and as to the man to whom it had been entrusted. The
# [0] Generated continuation:
# countess and the countess and the countess and the
# [61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38]
#
# 1.38393, 1.4996, 1.45016, 1.53658, 1.44813, 1.5916, 1.60682, 1.37384, 1.50443, 1.62305, [1000] Input text:
# side him, what he thought of tomorrow's battle. Kutuzov looked sternly at his adjutant and, after a
# [1000] Generated continuation:
# soldiers and the countess and the countess and the
# [22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38]
#
# 1.57653, 1.45425, 1.56851, 1.31428, 1.50782, 1.41698, 1.36741, 1.36404, 1.33827, 1.71497, [2000] Input text:
#  cross with me?" She concluded from his tone that he was vexed with her and wished to end the conver
# [2000] Generated continuation:
# sation of the countess and the countess and the co
# [22, 52, 69, 79, 9, 13, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9]
#
# 1.53902, 1.60052, 1.33502, 1.55552, 1.52759, 1.43098, 1.40581, 1.49456, 1.5787, 1.33736, [3000] Input text:
# choice of a new ruler for France. It is very difficult for events to be reflected in their real stre
# [3000] Generated continuation:
# ngth of the same that the same that the soldiers a
# [13, 31, 69, 43, 11, 9, 65, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 69, 43, 52, 69, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 69, 43, 52, 69, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52]
#
# 1.44397, 1.59366, 1.50868, 1.38515, 1.44926, 1.43982, 1.42869, 1.52793, 1.38691, 1.44121, [4000] Input text:
#  affairs had not improved during the two years they had spent in the country. Though Nicholas Rostov
# [4000] Generated continuation:
#  was a soldiers and the soldiers and the soldiers
# [11, 25, 52, 22, 11, 52, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11]
#
# 1.55857, 1.62367, 1.37932, 1.49677, 1.55811, 1.47286, 1.43561, 1.43836, 1.48821, 1.45948, [5000] Input text:
# e vehement, scolded, and sometimes flung the exercise book away. The princess gave a wrong answer. "
# [5000] Generated continuation:
# What is the same to the sound of the same to the s
# [27, 43, 52, 69, 11, 79, 22, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 69, 9, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 69, 9, 11, 69, 43, 38, 11, 22]
#
# 1.67283, 1.25779, 1.51485, 1.53658, 1.26998, 1.33089, 1.48999, 1.50718, 1.40737, 1.40529, [6000] Input text:
# e was received. Everybody laughed. "Your joke is too bad, it's witty but unjust," said Anna Pavlovna
# [6000] Generated continuation:
#  continued the count hand the count hand the count
# [11, 61, 9, 13, 69, 79, 13, 73, 38, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 43, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 43, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69]
#
# 1.41918, 1.48928, 1.54843, 1.60511, 1.35224, 1.42882, 1.25487, 1.567, 1.35116, 1.32503, [7000] Input text:
# y General Campan (who was to attack the fleches) to lead his division through the woods, Napoleon ag
# [7000] Generated continuation:
# ain the contrary which he had been the contrary wh
# [52, 79, 13, 11, 69, 43, 38, 11, 61, 9, 13, 69, 72, 52, 72, 42, 11, 25, 43, 79, 61, 43, 11, 43, 38, 11, 43, 52, 78, 11, 12, 38, 38, 13, 11, 69, 43, 38, 11, 61, 9, 13, 69, 72, 52, 72, 42, 11, 25, 43]
#
# 1.52284, 1.53024, 1.24917, 1.48571, 1.78585, 1.45215, 1.42259, 1.33981, 1.39969, 1.36958, [8000] Input text:
# , a trowel, a rough stone and a squared stone, a pillar, three windows, and so on. Then a place was
# [8000] Generated continuation:
# the count of the count of the count of the strengt
# [69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 72, 38, 13, 31, 69]
#
# 1.20857, 1.53871, 1.52411, 1.51722, 1.41776, 1.46674, 1.64474, 1.37262, 1.54094, 1.77386, [9000] Input text:
# the words being inserted that he would not make peace so long as a single armed Frenchman remained o
# [9000] Generated continuation:
# n the soldiers and the countess and the countess a
# [13, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52]
#
# 1.51953, 1.47953, 1.42979, 1.66305, 1.52701, 1.43636, 1.46392, 1.39654, 1.53949, 1.71573, [10000] Input text:
# the first moments of the reception over. The band played the polonaise in vogue at that time on acco
# [10000] Generated continuation:
# unt of the soldiers and the commander of the soldi
# [73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 56, 56, 52, 13, 78, 38, 72, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79]
#
# 1.49421, 1.43199, 1.51832, 1.36467, 1.40292, 1.48643, 1.60498, 1.23261, 1.55658, 1.62469, [11000] Input text:
# d not the face she had known ever since she could remember and had always seen at a distance, but th
# [11000] Generated continuation:
# e conversation of the soldiers and the conversatio
# [38, 11, 61, 9, 13, 16, 38, 72, 22, 52, 69, 79, 9, 13, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 13, 16, 38, 72, 22, 52, 69, 79, 9]
#
# 1.59834, 1.51225, 1.34821, 1.49763, 1.28765, 1.50327, 1.49034, 1.48796, 1.48324, 1.35628, [12000] Input text:
# egs out of the gully, and having disengaged herself from the dogs, with tail tucked in again, went f
# [12000] Generated continuation:
# or the sound of the soldiers and the countess whic
# [9, 72, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 25, 43, 79, 61]
#
# 1.45961, 1.6343, 1.43333, 1.41375, 1.42245, 1.27886, 1.46741, 1.62259, 1.40806, 1.74619, [13000] Input text:
# ised had he been absent. Boris lodged with another adjutant, the Polish Count Zhilinski. Zhilinski,
# [13000] Generated continuation:
# and the countess and the countess and the countess
# [52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22]
#
# ...
# asked on behalf of all who begged of him, he would soon be unable to ask for himself, he became char
# [1000] Generated continuation:
# ding the strange and the door and the door of the
# [78, 79, 13, 31, 11, 69, 43, 38, 11, 22, 69, 72, 52, 13, 31, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 78, 9, 9, 72, 11, 52, 13, 78, 11, 69, 43, 38, 11, 78, 9, 9, 72, 11, 9, 65, 11, 69, 43, 38, 11]
#
# 1.40183, 1.68709, 1.41121, 1.4331, 1.26614, 1.3969, 1.49856, 1.72127, 1.33333, 1.24285, [2000] Input text:
# he bridge leading to the village, not more than five hundred yards away, crowds of men could be seen
# [2000] Generated continuation:
#  the same and the counte and the countess and the
# [11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11]
#
# 1.3848, 1.63861, 1.41596, 1.27763, 1.38653, 1.52228, 1.3774, 1.345, 1.47305, 1.3482, [3000] Input text:
#  he had already passed it. He would not soon have remembered this, such was his state of forgetfulne
# [3000] Generated continuation:
# ss of the stranger and the stranger and the strang
# [22, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 72, 52, 13, 31, 38, 72, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 72, 52, 13, 31, 38, 72, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 72, 52, 13, 31]
#
# 1.42335, 1.39314, 1.27625, 1.35167, 1.58638, 1.46918, 1.56561, 1.53737, 1.46414, 1.23494, [4000] Input text:
# g above it. A few minutes later it reappeared brighter still from behind the top of the cloud, teari
# [4000] Generated continuation:
# ng the street of the soldiers of the street of the
# [13, 31, 11, 69, 43, 38, 11, 22, 69, 72, 38, 38, 69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 72, 38, 38, 69, 11, 9, 65, 11, 69, 43, 38]
#
# 1.29145, 1.52552, 1.31309, 1.23437, 1.42773, 1.55648, 1.6326, 1.50912, 1.4945, 1.39261, [5000] Input text:
# ive an opinion at the war council which would be the only one that could save the army, and how he a
# [5000] Generated continuation:
# sked the soldiers and the count of the soldiers an
# [22, 58, 38, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13]
#
# 1.49192, 1.35854, 1.32802, 1.42532, 1.47529, 1.21855, 1.45863, 1.33372, 1.5865, 1.48253, [6000] Input text:
# ed in front of the Preobrazhensk regiment, sighed deeply, and closed his eyes. One of his suite beck
# [6000] Generated continuation:
# use the street of the street of the street of the
# [73, 22, 38, 11, 69, 43, 38, 11, 22, 69, 72, 38, 38, 69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 72, 38, 38, 69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 72, 38, 38, 69, 11, 9, 65, 11, 69, 43, 38, 11]
#
# 1.28805, 1.49644, 1.46453, 1.59778, 1.40917, 1.32123, 1.57954, 1.44704, 1.58805, 1.3869, [7000] Input text:
# g home Petya announced resolutely and firmly that if he was not allowed to enter the service he woul
# [7000] Generated continuation:
# d be a sourte of the sounds of the sounds of the s
# [78, 11, 12, 38, 11, 52, 11, 22, 9, 73, 72, 69, 38, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22]
#
# 1.41926, 1.59035, 1.29208, 1.39527, 1.5353, 1.26519, 1.30976, 1.45608, 1.29578, 1.49078, [8000] Input text:
# r how intolerable it had been for him to meet ladies at dinners and balls in Petersburg. "I have qui
# [8000] Generated continuation:
# te to do it was a soldiers and the soul. I have be
# [69, 38, 11, 69, 9, 11, 78, 9, 11, 79, 69, 11, 25, 52, 22, 11, 52, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 73, 2, 81, 11, 23, 11, 43, 52, 16, 38, 11, 12, 38]
#
# 1.4572, 1.36274, 1.42176, 1.33253, 1.51279, 1.29348, 1.44767, 1.6545, 1.21105, 1.55679, [9000] Input text:
# occupied by the Emperors and their retinues. That same day a council of war had been held in which a
# [9000] Generated continuation:
# nd the soldiers and the soldiers and the soldiers
# [13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11]
#
# 1.41484, 1.40251, 1.21451, 1.36088, 1.37883, 1.36087, 1.49144, 1.40411, 1.25603, 1.26183, [10000] Input text:
# urienne, with her ribbon and pretty face, and her unusually animated look which was fixed on him, bu
# [10000] Generated continuation:
# t the countess and the soldiers and the soldiers a
# [69, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52]
#
# 1.39134, 1.41256, 1.50923, 1.4946, 1.39555, 1.50801, 1.65176, 1.38378, 1.33173, 1.4231, [11000] Input text:
#  week later, Pierre, having taken leave of his new friends, the Masons, and leaving large sums of mo
# [11000] Generated continuation:
# ment of the door of the door of the door of the do
# [56, 38, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 78, 9, 9, 72, 11, 9, 65, 11, 69, 43, 38, 11, 78, 9, 9, 72, 11, 9, 65, 11, 69, 43, 38, 11, 78, 9, 9, 72, 11, 9, 65, 11, 69, 43, 38, 11, 78, 9]
#
# 1.27337, 1.52601, 1.52639, 1.31564, 1.29594, 1.49959, 1.22909, 1.40395, 1.28175, 1.48157, [12000] Input text:
#  only to repeat it again and again. There was now not a shadow of doubt in his mind as to whether wh
# [12000] Generated continuation:
# en he had been should be said to him and should be
# [38, 13, 11, 43, 38, 11, 43, 52, 78, 11, 12, 38, 38, 13, 11, 22, 43, 9, 73, 2, 78, 11, 12, 38, 11, 22, 52, 79, 78, 11, 69, 9, 11, 43, 79, 56, 11, 52, 13, 78, 11, 22, 43, 9, 73, 2, 78, 11, 12, 38]
#
# 1.39767, 1.54374, 1.88099, 1.37854, 1.52641, 1.53455, 1.54011, 1.20341, 1.42972, 1.48479, [13000] Input text:
# ce Vasili interrupted him. "And why didn't you simply come straight to me as to a friend? I know all
# [13000] Generated continuation:
#  the sound of the sound of the sound of the sound
# [11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11]
#
# 1.46771, 1.4551, 1.44478, 1.38165, 1.57957, 1.35873, 1.4575, 1.38972, 1.42148, 1.51808, [14000] Input text:
# e afternoon," replied Bolkonski growing more animated and expecting that he would have a chance to g
# [14000] Generated continuation:
# et a state and the countess and the countess and t
# [38, 69, 11, 52, 11, 22, 69, 52, 69, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69]
#
# 1.3161, 1.32607, 1.36415, 1.56407, 1.62305, 1.46151, 1.30942, 1.39941, 1.14741, 1.41606, [15000] Input text:
# he officers don't keep them in hand. And there," he pointed to a sutler's tent, "they crowd in and s
# [15000] Generated continuation:
# ome time to the countess and the countess and the
# [9, 56, 38, 11, 69, 79, 56, 38, 11, 69, 9, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11]
#
# 1.50865, 1.30773, 1.53154, 1.46134, 1.43439, 1.37092, 1.60222, 1.38275, 1.08049, 1.314, [16000] Input text:
# ad out before him, and summoned Lelorgne d'Ideville, the interpreter. * "That Asiatic city of the in
# [16000] Generated continuation:
# terest of the count of the count of the count of t
# [69, 38, 72, 38, 22, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69]
#
# 1.30031, [0] Input text:
# intance. But as soon as Denisov smiled at him Petya brightened up, blushed with pleasure, forgot the
# [0] Generated continuation:
#  soldiers and the soldiers and the soldiers and th
# [11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43]
#
# 1.56506, 1.50676, 1.33036, 1.56507, 1.47992, 1.46106, 1.36056, 1.22473, 1.45664, 1.21601, [1000] Input text:
#  ever forgive me? Will he not always have a bitter feeling toward me? What do you think? What do you
# [1000] Generated continuation:
#  know the continual and the continual and the cont
# [11, 58, 13, 9, 25, 11, 69, 43, 38, 11, 61, 9, 13, 69, 79, 13, 73, 52, 2, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 13, 69, 79, 13, 73, 52, 2, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 13, 69]
#
# 1.46648, 1.30147, 1.26853, 1.66404, 1.34376, 1.51963, 1.47767, 1.32748, 1.35737, 1.42663, [2000] Input text:
#  to the ground. At the same instant he was dazzled by a great flash of flame, and immediately a deaf
# [2000] Generated continuation:
# h that the countess and the streets and the street
# [43, 11, 69, 43, 52, 69, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 72, 38, 38, 69, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 72, 38, 38, 69]
#
# 1.49135, 1.46577, 1.26501, 1.33001, 1.39959, 1.49192, 1.56139, 1.36968, 1.56176, 1.44204, [3000] Input text:
# s relations was the fact that there was still a possibility of his having been picked up on the batt
# [3000] Generated continuation:
# le of the sound of the sound of the sound of the s
# [2, 38, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 73, 13, 78, 11, 9, 65, 11, 69, 43, 38, 11, 22]
#
# 1.36905, 1.46219, 1.57499, 1.43074, 1.40169, 1.39286, 1.45064, 1.65379, 1.49819, 1.41387, [4000] Input text:
# Natasha, not as he had done in the past with nothing but her charms which gave him delight, but for
# [4000] Generated continuation:
# the countess and the countess and the countess and
# [69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78]
#
# 1.47988, 1.25624, 1.44685, 1.28864, 1.41351, 1.44715, 1.36104, 1.43669, 1.47241, 1.25858, [5000] Input text:
# e eBooks, unless you receive specific permission. If you do not charge anything for copies of this e
# [5000] Generated continuation:
# xpression of the same time to the same time to the
# [32, 19, 72, 38, 22, 22, 79, 9, 13, 11, 9, 65, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 69, 79, 56, 38, 11, 69, 9, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 69, 79, 56, 38, 11, 69, 9, 11, 69, 43, 38]
#
# 1.33299, 1.4276, 1.47032, 1.21362, 1.36514, 1.43067, 1.41482, 1.53751, 1.24322, 1.31677, [6000] Input text:
# ut me up, he said I was telling an untruth." "Well, have it so, and you talked a lot of nonsense to
# [6000] Generated continuation:
# the Emperor was the same man in the standing and t
# [69, 43, 38, 11, 54, 56, 19, 38, 72, 9, 72, 11, 25, 52, 22, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 56, 52, 13, 11, 79, 13, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 52, 13, 78, 11, 69]
#
# 1.32243, 1.53037, 1.41642, 1.28882, 1.51556, 1.47281, 1.51492, 1.41719, 1.45034, 1.40646, [7000] Input text:
# hird consideration is the degree to which we apprehend that endless chain of causation inevitably de
# [7000] Generated continuation:
# ar face to the count of the standing to the standi
# [52, 72, 11, 65, 52, 61, 38, 11, 69, 9, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79, 13, 31, 11, 69, 9, 11, 69, 43, 38, 11, 22, 69, 52, 13, 78, 79]
#
# 1.53567, 1.43562, 1.46015, 1.35567, 1.35638, 1.51726, 1.62307, 1.6131, 1.31028, 1.40135, [8000] Input text:
#  everybody's way. He really was in their way, for he alone took no part in the conversation which ag
# [8000] Generated continuation:
# ain the strength of the princess and the stopper w
# [52, 79, 13, 11, 69, 43, 38, 11, 22, 69, 72, 38, 13, 31, 69, 43, 11, 9, 65, 11, 69, 43, 38, 11, 19, 72, 79, 13, 61, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 69, 9, 19, 19, 38, 72, 11, 25]
#
# 1.53263, 1.55704, 1.25094, 1.38509, 1.53514, 1.43121, 1.29745, 1.56929, 1.34745, 1.45358, [9000] Input text:
# here the steward's high bedstead stood with its patchwork quilt. The young count paid no heed to the
# [9000] Generated continuation:
#  soldiers and the soldiers and the soldiers and th
# [11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43]
#
# 1.35146, 1.37986, 1.40191, 1.42656, 1.34274, 1.37398, 1.50259, 1.48144, 1.37926, 1.55691, [10000] Input text:
# idge unobserved, flings the bags of incendiary material into the water, and approaches the tête-de-p
# [10000] Generated continuation:
# er and the count and the count and the count and t
# [38, 72, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 11, 52, 13, 78, 11, 69]
#
# 1.32784, 1.20579, 1.52714, 1.36154, 1.26949, 1.36914, 1.24187, 1.32092, 1.47321, 1.304, [11000] Input text:
# ?" he asked. "Hiding?" "She is not very well," answered Mademoiselle Bourienne with a bright smile,
# [11000] Generated continuation:
# and the countess and the soldiers and the soldiers
# [52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22]
#
# 1.56757, 1.46398, 1.53437, 1.41754, 1.33255, 1.49251, 1.29317, 1.38759, 1.49617, 1.66869, [12000] Input text:
# ow they scurry. He just sends a ball and they think they'll all be killed," a sergeant was saying an
# [12000] Generated continuation:
# d the soldiers of the soldiers of the soldiers of
# [78, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11, 69, 43, 38, 11, 22, 9, 2, 78, 79, 38, 72, 22, 11, 9, 65, 11]
#
# 1.65461, 1.42372, 1.26506, 1.24389, 1.34145, 1.42264, 1.29539, 1.10322, 1.27181, 1.41563, [13000] Input text:
# guished wife, a clever crank who did nothing but harmed nobody and was a first-rate, good-natured fe
# [13000] Generated continuation:
# llows and should be any of the same and the same o
# [2, 2, 9, 25, 22, 11, 52, 13, 78, 11, 22, 43, 9, 73, 2, 78, 11, 12, 38, 11, 52, 13, 42, 11, 9, 65, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 22, 52, 56, 38, 11, 9]
#
# 1.42089, 1.35351, 1.25762, 1.27017, 1.53078, 1.24384, 1.41988, 1.37081, 1.12481, 1.35708, [14000] Input text:
# arshal Junot's enormous baggage train, convoyed by Westphalians. Behind the prisoners came a cavalry
# [14000] Generated continuation:
#  and seemed to him and seemed to him and seemed to
# [11, 52, 13, 78, 11, 22, 38, 38, 56, 38, 78, 11, 69, 9, 11, 43, 79, 56, 11, 52, 13, 78, 11, 22, 38, 38, 56, 38, 78, 11, 69, 9, 11, 43, 79, 56, 11, 52, 13, 78, 11, 22, 38, 38, 56, 38, 78, 11, 69, 9]
#
# 1.59475, 1.28936, 1.40894, 1.23638, 1.65418, 1.38915, 1.377, 1.48425, 1.25652, 1.40543, [15000] Input text:
# rival Prince Andrew, as a gentleman of the chamber, presented himself at court and at a levee. The E
# [15000] Generated continuation:
# mperor was a strange and the countess and the coun
# [56, 19, 38, 72, 9, 72, 11, 25, 52, 22, 11, 52, 11, 22, 69, 72, 52, 13, 31, 38, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13, 69, 38, 22, 22, 11, 52, 13, 78, 11, 69, 43, 38, 11, 61, 9, 73, 13]
#
# 1.39286, 1.24549, 1.29104, 1.20331, 1.39473, 1.56895, 1.29603, 1.36264, 1.3479, 1.58779, [16000] Input text:
#  Tikhon; he looked at his watch as if to ascertain whether his father's habits had changed since he
# [16000] Generated continuation:
# had been a service to the state of the state of th
# [43, 52, 78, 11, 12, 38, 38, 13, 11, 52, 11, 22, 38, 72, 16, 79, 61, 38, 11, 69, 9, 11, 69, 43, 38, 11, 22, 69, 52, 69, 38, 11, 9, 65, 11, 69, 43, 38, 11, 22, 69, 52, 69, 38, 11, 9, 65, 11, 69, 43]
